# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('Car details v3.csv')

# %%
data.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
data.shape
# Out:
# (8128, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
data.isnull()
# Out:
#        name   year  selling_price  km_driven   fuel  seller_type  \
# 0     False  False          False      False  False        False
# 1     False  False          False      False  False        False
# 2     False  False          False      False  False        False
# 3     False  False          False      False  False        False
# 4     False  False          False      False  False        False
# ...     ...    ...            ...        ...    ...          ...
# 8123  False  False          False      False  False        False
# 8124  False  False          False      False  False        False
# 8125  False  False          False      False  False        False
# 8126  False  False          False      False  False        False
# 8127  False  False          False      False  False        False
#
#       transmission  owner  mileage  engine  max_power  torque  seats
# 0            False  False    False   False      False   False  False
# ...

# %%
data.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
data.head(1)
# Out:
#                      name  year  selling_price  km_driven    fuel seller_type  \
# 0  Maruti Swift Dzire VDI  2014         450000     145500  Diesel  Individual
#
#   transmission        owner    mileage   engine max_power          torque  \
# 0       Manual  First Owner  23.4 kmpl  1248 CC    74 bhp  190Nm@ 2000rpm
#
#    seats
# 0    5.0

# %%
import datetime

# %%
date_time = datetime.datetime.now()

# %%
data['Age'] = date_time.year - data['year']

# %%
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data.drop('year',axis=1,inplace=True)

# %%
data.head()
# Out:
#                            name  selling_price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI         450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition         370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi         158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel         225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII         130000     120000  Petrol  Individual
#
#   transmission         owner     mileage   engine   max_power  \
# 0       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  Age
# 0            190Nm@ 2000rpm    5.0   10
# 1       250Nm@ 1500-2500rpm    5.0   10
# ...

# %%
sns.boxplot(data['selling_price'])
# Out:
# <Axes: >

# %%
sorted(data['selling_price'],reverse = True)
# Out:
# [10000000,
#  7200000,
#  6523000,
#  6223000,
#  6000000,
#  6000000,
#  6000000,
#  6000000,
#  6000000,
#  6000000,
#  5923000,
#  5850000,
#  5830000,
#  5830000,
#  5800000,
#  5800000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5500000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5400000,
#  5200000,
#  5200000,
#  5200000,
#  5200000,
# ...

# %%
data = data[~(data['selling_price']>=7200000 )& (data['selling_price']<=10000000)]

# %%
data.shape
# Out:
# (8126, 13)

# %%
data.head(1)
# Out:
#                      name  selling_price  km_driven    fuel seller_type  \
# 0  Maruti Swift Dzire VDI         450000     145500  Diesel  Individual
#
#   transmission        owner    mileage   engine max_power          torque  \
# 0       Manual  First Owner  23.4 kmpl  1248 CC    74 bhp  190Nm@ 2000rpm
#
#    seats  Age
# 0    5.0   10

# %%
data['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
data['fuel'] = data['fuel'].map({'Diesel':0,'Petrol':1,'LPG':2,'CNG':3})

# %%
data['fuel'].unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
data['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
data['seller_type'] = data['seller_type'].map({'Dealer':1,'Individual':0,'Trustmark Dealer':2})

# %%
data['seller_type'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
data['transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
data['transmission'] = data['transmission'].map({'Manual':0,'Automatic':1})

# %%
data['transmission'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data.head()
# Out:
#                            name  selling_price  km_driven  fuel  seller_type  \
# 0        Maruti Swift Dzire VDI         450000     145500     0            0
# 1  Skoda Rapid 1.5 TDI Ambition         370000     120000     0            0
# 2      Honda City 2017-2020 EXi         158000     140000     1            0
# 3     Hyundai i20 Sportz Diesel         225000     127000     0            0
# 4        Maruti Swift VXI BSIII         130000     120000     1            0
#
#    transmission         owner     mileage   engine   max_power  \
# 0             0   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1             0  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2             0   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3             0   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4             0   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  Age
# 0            190Nm@ 2000rpm    5.0   10
# 1       250Nm@ 1500-2500rpm    5.0   10
# ...

# %%
data['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %%
data['owner'] = data['owner'].map({'First Owner':0,'Second Owner':1,'Third Owner':2,'Fourth & Above Owner':3,'Test Drive Car':4})

# %%
data['owner'].unique()
# Out:
# array([0, 1, 2, 3, 4], dtype=int64)

# %%
data.head()
# Out:
#                            name  selling_price  km_driven  fuel  seller_type  \
# 0        Maruti Swift Dzire VDI         450000     145500     0            0
# 1  Skoda Rapid 1.5 TDI Ambition         370000     120000     0            0
# 2      Honda City 2017-2020 EXi         158000     140000     1            0
# 3     Hyundai i20 Sportz Diesel         225000     127000     0            0
# 4        Maruti Swift VXI BSIII         130000     120000     1            0
#
#    transmission  owner     mileage   engine   max_power  \
# 0             0      0   23.4 kmpl  1248 CC      74 bhp
# 1             0      1  21.14 kmpl  1498 CC  103.52 bhp
# 2             0      2   17.7 kmpl  1497 CC      78 bhp
# 3             0      0   23.0 kmpl  1396 CC      90 bhp
# 4             0      0   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  Age
# 0            190Nm@ 2000rpm    5.0   10
# 1       250Nm@ 1500-2500rpm    5.0   10
# 2     12.7@ 2,700(kgm@ rpm)    5.0   18
# ...

# %%
# data['mileage'].str.split(' ').str.get(0).str.replace(',','')

# %%
data['mileage'] = data['mileage'].str.split(' ').str.get(0).str.replace(',', '')

# %%
data['mileage'] =data['mileage'].str.split('.').str.get(0)

# %%
data['mileage'].unique()
# Out:
# array(['23', '21', '17', '16', '20', '19', nan, '18', '24', '22', '25',
#        '26', '14', '33', '13', '12', '27', '11', '15', '9', '10', '28',
#        '0', '30', '32'], dtype=object)

# %%
data.head()
# Out:
#                            name  selling_price  km_driven  fuel  seller_type  \
# 0        Maruti Swift Dzire VDI         450000     145500     0            0
# 1  Skoda Rapid 1.5 TDI Ambition         370000     120000     0            0
# 2      Honda City 2017-2020 EXi         158000     140000     1            0
# 3     Hyundai i20 Sportz Diesel         225000     127000     0            0
# 4        Maruti Swift VXI BSIII         130000     120000     1            0
#
#    transmission  owner mileage   engine   max_power                    torque  \
# 0             0      0      23  1248 CC      74 bhp            190Nm@ 2000rpm
# 1             0      1      21  1498 CC  103.52 bhp       250Nm@ 1500-2500rpm
# 2             0      2      17  1497 CC      78 bhp     12.7@ 2,700(kgm@ rpm)
# 3             0      0      23  1396 CC      90 bhp  22.4 kgm at 1750-2750rpm
# 4             0      0      16  1298 CC    88.2 bhp     11.5@ 4,500(kgm@ rpm)
#
#    seats  Age
# 0    5.0   10
# ...

# %%
data['engine'] =  data['engine'].str.split(' ').str.get(0).str.replace(',', '')

# %%
data['max_power'] =  data['max_power'].str.split(' ').str.get(0).str.replace(',', '')

# %%
data['max_power'] = data['max_power'].str.split('.').str.get(0).str.replace(',', '')

# %%
data.drop(columns=['torque'], inplace=True)

# %%
data.head()
# Out:
#                            name  selling_price  km_driven  fuel  seller_type  \
# 0        Maruti Swift Dzire VDI         450000     145500     0            0
# 1  Skoda Rapid 1.5 TDI Ambition         370000     120000     0            0
# 2      Honda City 2017-2020 EXi         158000     140000     1            0
# 3     Hyundai i20 Sportz Diesel         225000     127000     0            0
# 4        Maruti Swift VXI BSIII         130000     120000     1            0
#
#    transmission  owner mileage engine max_power  seats  Age
# 0             0      0      23   1248        74    5.0   10
# 1             0      1      21   1498       103    5.0   10
# 2             0      2      17   1497        78    5.0   18
# 3             0      0      23   1396        90    5.0   14
# 4             0      0      16   1298        88    5.0   17

# %%
data['name'] = data['name'].str.split(' ').str.get(1).str.replace(',', '')

# %%
data.shape
# Out:
# (8126, 12)

# %%
data.dropna(inplace = True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7905 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7905 non-null   object
#  1   selling_price  7905 non-null   int64
#  2   km_driven      7905 non-null   int64
#  3   fuel           7905 non-null   int64
#  4   seller_type    7905 non-null   int64
#  5   transmission   7905 non-null   int64
#  6   owner          7905 non-null   int64
#  7   mileage        7905 non-null   object
#  8   engine         7905 non-null   object
#  9   max_power      7905 non-null   object
#  10  seats          7905 non-null   float64
#  11  Age            7905 non-null   int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 802.9+ KB

# %%
data.head()
# Out:
#     name  selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0  Swift         450000     145500     0            0             0      0
# 1  Rapid         370000     120000     0            0             0      1
# 2   City         158000     140000     1            0             0      2
# 3    i20         225000     127000     0            0             0      0
# 4  Swift         130000     120000     1            0             0      0
#
#   mileage engine max_power  seats  Age
# 0      23   1248        74    5.0   10
# 1      21   1498       103    5.0   10
# 2      17   1497        78    5.0   18
# 3      23   1396        90    5.0   14
# 4      16   1298        88    5.0   17

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7905 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7905 non-null   object
#  1   selling_price  7905 non-null   int64
#  2   km_driven      7905 non-null   int64
#  3   fuel           7905 non-null   int64
#  4   seller_type    7905 non-null   int64
#  5   transmission   7905 non-null   int64
#  6   owner          7905 non-null   int64
#  7   mileage        7905 non-null   object
#  8   engine         7905 non-null   object
#  9   max_power      7905 non-null   object
#  10  seats          7905 non-null   float64
#  11  Age            7905 non-null   int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 802.9+ KB

# %%
data['mileage'] = data['mileage'].astype(int)

# %%
data['engine'] = data['engine'].astype(int)

# %%
data.drop(columns=['max_power'], inplace=True)

# %%
null_var = data.isnull().sum()/data.shape[0]*100
null_var
# Out:
# name             0.0
# selling_price    0.0
# km_driven        0.0
# fuel             0.0
# seller_type      0.0
# transmission     0.0
# owner            0.0
# mileage          0.0
# engine           0.0
# seats            0.0
# Age              0.0
# dtype: float64

# %%
data
# Out:
#         name  selling_price  km_driven  fuel  seller_type  transmission  \
# 0      Swift         450000     145500     0            0             0
# 1      Rapid         370000     120000     0            0             0
# 2       City         158000     140000     1            0             0
# 3        i20         225000     127000     0            0             0
# 4      Swift         130000     120000     1            0             0
# ...      ...            ...        ...   ...          ...           ...
# 8123     i20         320000     110000     1            0             0
# 8124   Verna         135000     119000     0            0             0
# 8125   Swift         382000     120000     0            0             0
# 8126  Indigo         290000      25000     0            0             0
# 8127  Indigo         290000      25000     0            0             0
#
#       owner  mileage  engine  seats  Age
# 0         0       23    1248    5.0   10
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.subplots(figsize=(35,7))
ax=sns.boxplot(x='name',y='selling_price',data=data )
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()

# %%
plt.subplots(figsize=(20,10))
ax=sns.swarmplot(x='Age',y='selling_price',data=data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()

# %%
sns.relplot(x='km_driven',y='selling_price',data=data,height=7,aspect=1.5)

# %%
plt.subplots(figsize=(10,5))
sns.boxplot(x='fuel',y='selling_price',data=data)
# Out:
# <Axes: xlabel='fuel', ylabel='selling_price'>

# %%
# filtered_data = data[data['fuel'] == 0]
# filtered_data

# %%
ax=sns.relplot(x='name',y='selling_price',data=data,hue='fuel',size='Age',height=10,aspect=6)
ax.set_xticklabels(rotation=40,ha='right')

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(['name','selling_price'],axis=1)
y = data['selling_price']

# %%
X
# Out:
#       km_driven  fuel  seller_type  transmission  owner  mileage  engine  \
# 0        145500     0            0             0      0       23    1248
# 1        120000     0            0             0      1       21    1498
# 2        140000     1            0             0      2       17    1497
# 3        127000     0            0             0      0       23    1396
# 4        120000     1            0             0      0       16    1298
# ...         ...   ...          ...           ...    ...      ...     ...
# 8123     110000     1            0             0      0       18    1197
# 8124     119000     0            0             0      3       16    1493
# 8125     120000     0            0             0      0       19    1248
# 8126      25000     0            0             0      0       23    1396
# 8127      25000     0            0             0      0       23    1396
#
#       seats  Age
# 0       5.0   10
# 1       5.0   10
# 2       5.0   18
# 3       5.0   14
# ...

# %%
y
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 8123    320000
# 8124    135000
# 8125    382000
# 8126    290000
# 8127    290000
# Name: selling_price, Length: 7905, dtype: int64

# %%
X_train, X_test, y_train , y_test =train_test_split(X,y,test_size=0.20,random_state = 42)
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6324 entries, 6893 to 7480
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   km_driven     6324 non-null   int64
#  1   fuel          6324 non-null   int64
#  2   seller_type   6324 non-null   int64
#  3   transmission  6324 non-null   int64
#  4   owner         6324 non-null   int64
#  5   mileage       6324 non-null   int32
#  6   engine        6324 non-null   int32
#  7   seats         6324 non-null   float64
#  8   Age           6324 non-null   int64
# dtypes: float64(1), int32(2), int64(6)
# memory usage: 444.7 KB

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
lr = LinearRegression()
lr.fit(X_train , y_train)

rf = RandomForestRegressor()
rf.fit(X_train , y_train)

xgb = GradientBoostingRegressor()
xgb.fit(X_train , y_train)

xg = XGBRegressor()
xg.fit(X_train , y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
null_var = data.isnull().sum()/data.shape[0]*100
null_var
# Out:
# name             0.0
# selling_price    0.0
# km_driven        0.0
# fuel             0.0
# seller_type      0.0
# transmission     0.0
# owner            0.0
# mileage          0.0
# engine           0.0
# seats            0.0
# Age              0.0
# dtype: float64

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = rf.predict(X_test)
y_pred3 = xgb.predict(X_test)
y_pred4 = xg.predict(X_test)

# %%
from sklearn import metrics

# %%
score1 = metrics.r2_score(y_test,y_pred1)
score2 = metrics.r2_score(y_test,y_pred2)
score3 = metrics.r2_score(y_test,y_pred3)
score4 = metrics.r2_score(y_test,y_pred4)

# %%
print(score1,score2,score3,score4)
# Out:
# 0.5476855165640628 0.9491331873614464 0.9284788354486407 0.9513423577546737

# %%
final_data = pd.DataFrame({'Models':['LR','RF','GBR','XG'],
             "R2_SCORE":[score1,score2,score3,score4]})

# %%
final_data
# Out:
#   Models  R2_SCORE
# 0     LR  0.547686
# 1     RF  0.949133
# 2    GBR  0.928479
# 3     XG  0.951342

# %%
sns.barplot(x=final_data['Models'], y= final_data['R2_SCORE'])
# Out:
# <Axes: xlabel='Models', ylabel='R2_SCORE'>

# %%
xg = XGBRegressor()
xg_final = xg.fit(X,y)

# %%
import joblib

# %%
joblib.dump(xg_final,'car_price_predictor')
# Out:
# ['car_price_predictor']

# %%
model = joblib.load('car_price_predictor')

# %%
data.head(1)
# Out:
#     name  selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0  Swift         450000     145500     0            0             0      0
#
#    mileage  engine  seats  Age
# 0       23    1248    5.0   10

# %%
import pandas as pd
data_new = pd.DataFrame({
#   'selling_price':450000,
    'km_driven':145500,
    'fuel':0,
    'seller_type':0,
    'transmission':0,
    'owner':0,
    'mileage':23,
    'engine':1248,
    'seats':5.0,
    'Age':8
},index=[0])

# %%
model.predict(data_new)
# Out:
# array([540079.8], dtype=float32)

# %%
 from tkinter import *
 import joblib

 def show_entry_fields():
     p1=float(e1.get())
     p2=float(e2.get())
     p3=float(e3.get())
     p4=float(e4.get())
     p5=float(e5.get())
     p6=float(e6.get())
     p7=float(e7.get())
     p8=float(e8.get())
     p9=float(e9.get())
     
     model = joblib.load('car_price_predictor')
     data_new = pd.DataFrame({
     'km_driven':p1,
     'fuel':p2,
     'seller_type':p3,
     'transmission':p4,
     'owner':p5,
     'mileage':p6,
     'engine':p7,
     'seats':p8,
     'Age':p9,
 },index=[0])
     result=model.predict(data_new)
     Label(master, text="Car Purchase amount").grid(row=8)
     Label(master, text=result).grid(row=10)
     print("Car Purchase amount", result[0])
   
 master = Tk()
 master.title("Car Price Prediction Using Machine Learning")
 label = Label(master, text = "Car Price Prediction Using Machine Learning"
                           , bg = "black", fg = "white"). \
                                grid(row=0,columnspan=2)

 Label(master, text="km_driven").grid(row=1)
 Label(master, text="Fuel_Type").grid(row=2)
 Label(master, text="Seller_Type").grid(row=3)
 Label(master, text="Transmission").grid(row=4)
 Label(master, text="Owner").grid(row=5)
 Label(master, text="mileage").grid(row=6)
 Label(master, text="engine").grid(row=7)
 Label(master, text="seats").grid(row=8)

 Label(master, text="Age").grid(row=9)

 e1 = Entry(master)
 e2 = Entry(master)
 e3 = Entry(master)
 e4 = Entry(master)
 e5 = Entry(master)
 e6 = Entry(master)
 e7 = Entry(master)
 e8 = Entry(master)
 e9 = Entry(master)



 e1.grid(row=1, column=1)
 e2.grid(row=2, column=1)
 e3.grid(row=3, column=1)
 e4.grid(row=4, column=1)
 e5.grid(row=5, column=1)
 e6.grid(row=6, column=1)
 e7.grid(row=7, column=1)
 e8.grid(row=8, column=1)
 e9.grid(row=9, column=1)  

 Button(master, text='Predict', command=show_entry_fields).grid()
 mainloop()
